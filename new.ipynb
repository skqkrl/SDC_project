# %%
import pandas as pd

# %%
import sys

# %%
print(sys.executable)
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df_2021_buy = pd.read_csv('/Users/minju/Desktop/project/연립다세대(매매)_실거래가_2021.csv', encoding='euc-kr', header=15)

# %%
df_2021_buy
# Out:
#           NO              시군구      번지   본번  부번           건물명  전용면적(㎡)  \
# 0          1  서울특별시 용산구 원효로1가   17-33   17  33       세종빌리지2차    50.46
# 1          2    서울특별시 성동구 도선동   329-1  329   1     에코하우스(1동)    12.25
# 2          3    서울특별시 중랑구 망우동   514-2  514   2         현대아트빌    29.18
# 3          4    서울특별시 성동구 홍익동    17-3   17   3         레이나D동    55.06
# 4          5     서울특별시 강북구 번동  437-78  437  78          진주8동    41.04
# ...      ...              ...     ...  ...  ..           ...      ...
# 60699  60700   서울특별시 영등포구 대림동  844-18  844  18  동서빌라(844-18)    50.75
# 60700  60701     서울특별시 구로구 궁동  283-11  283  11  인화빌라(283-11)    36.98
# 60701  60702    서울특별시 구로구 구로동  797-27  797  27      (797-27)    43.16
# 60702  60703   서울특별시 영등포구 대림동   993-4  993   4    현대그린빌라A,B동    72.72
# 60703  60704    서울특별시 강서구 등촌동  647-68  647  68         이건하우스    47.94
#
#        대지권면적(㎡)    계약년월  계약일 거래금액(만원)  층 매수자 매도자  건축년도           도로명 해제사유발생일  \
# ...

# %%
df_2021_buy.isnull().sum()
# Out:
# NO          0
# 시군구         0
# 번지          0
# 본번          0
# 부번          0
# 건물명         0
# 전용면적(㎡)     0
# 대지권면적(㎡)    0
# 계약년월        0
# 계약일         0
# 거래금액(만원)    0
# 층           0
# 매수자         0
# 매도자         0
# 건축년도        0
# 도로명         0
# 해제사유발생일     0
# 거래유형        0
# 중개사소재지      0
# 등기일자        0
# dtype: int64

# %%
df_2021_buy['계약년월'].min(), df_2021_buy['계약년월'].max()
# Out:
# (np.int64(202101), np.int64(202112))

# %%
df_2021_buy.sort_values(by='계약년월',ascending=True)
# Out:
#           NO              시군구       번지   본번   부번         건물명  전용면적(㎡)  \
# 60703  60704    서울특별시 강서구 등촌동   647-68  647   68       이건하우스    47.94
# 56481  56482    서울특별시 강동구 천호동   220-11  220   11       경원쉐르빌    44.88
# 56482  56483    서울특별시 강동구 천호동    25-36   25   36       예가풍경채    42.05
# 56483  56484    서울특별시 강동구 천호동    337-3  337    3  하우징허브바람개비1    30.40
# 56484  56485    서울특별시 송파구 마천동   200-23  200   23    (200-23)    34.23
# ...      ...              ...      ...  ...  ...         ...      ...
# 2384    2385    서울특별시 서초구 양재동    123-2  123    2        금성빌라    69.30
# 2383    2384    서울특별시 서초구 양재동    383-6  383    6       다인빌리지    76.44
# 2382    2383    서울특별시 서초구 양재동   386-24  386   24   동산마루빌102동    55.73
# 2688    2689    서울특별시 마포구 연남동  487-432  487  432        오네스타    48.24
# 0          1  서울특별시 용산구 원효로1가    17-33   17   33     세종빌리지2차    50.46
#
#        대지권면적(㎡)    계약년월  계약일 거래금액(만원)  층 매수자 매도자  건축년도            도로명 해제사유발생일  \
# ...

# %%
df_2021_buy.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_2021_buy.dtypes
# Out:
# NO            int64
# 시군구          object
# 번지           object
# 본번            int64
# 부번            int64
# 건물명          object
# 전용면적(㎡)     float64
# 대지권면적(㎡)    float64
# 계약년월          int64
# 계약일           int64
# 거래금액(만원)     object
# 층             int64
# 매수자          object
# 매도자          object
# 건축년도          int64
# 도로명          object
# 해제사유발생일      object
# 거래유형         object
# 중개사소재지       object
# 등기일자         object
# dtype: object

# %%
df_2021_buy.sort_values(by='계약년월',ascending=True)
# Out:
#           NO              시군구       번지   본번   부번         건물명  전용면적(㎡)  \
# 60703  60704    서울특별시 강서구 등촌동   647-68  647   68       이건하우스    47.94
# 56481  56482    서울특별시 강동구 천호동   220-11  220   11       경원쉐르빌    44.88
# 56482  56483    서울특별시 강동구 천호동    25-36   25   36       예가풍경채    42.05
# 56483  56484    서울특별시 강동구 천호동    337-3  337    3  하우징허브바람개비1    30.40
# 56484  56485    서울특별시 송파구 마천동   200-23  200   23    (200-23)    34.23
# ...      ...              ...      ...  ...  ...         ...      ...
# 2384    2385    서울특별시 서초구 양재동    123-2  123    2        금성빌라    69.30
# 2383    2384    서울특별시 서초구 양재동    383-6  383    6       다인빌리지    76.44
# 2382    2383    서울특별시 서초구 양재동   386-24  386   24   동산마루빌102동    55.73
# 2688    2689    서울특별시 마포구 연남동  487-432  487  432        오네스타    48.24
# 0          1  서울특별시 용산구 원효로1가    17-33   17   33     세종빌리지2차    50.46
#
#        대지권면적(㎡)    계약년월  계약일 거래금액(만원)  층 매수자 매도자  건축년도            도로명 해제사유발생일  \
# ...

# %% [markdown]
# 뭐야

# %%
df_2021_buy.columns
# Out:
# Index(['NO', '시군구', '번지', '본번', '부번', '건물명', '전용면적(㎡)', '대지권면적(㎡)', '계약년월',
#        '계약일', '거래금액(만원)', '층', '매수자', '매도자', '건축년도', '도로명', '해제사유발생일', '거래유형',
#        '중개사소재지', '등기일자'],
#       dtype='object')

# %%
df_2021_buy.drop_duplicates(inplace=True)
