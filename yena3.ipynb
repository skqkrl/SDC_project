# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# ### 단독/다가구

# %%
multi_household = pd.read_csv('D:/SDC_project/단독다가구_전세가율.csv')
multi_household
# Out:
#                    시군구  전용면적(㎡)    계약년월  계약일    전세금    건축년도        도로명  \
# 0        서울특별시 성동구 행당동    42.00  202412   31  14000  1998.0      마조로1길
# 1        서울특별시 용산구 서계동    26.45  202412   31   3000  1944.0  효창원로104라길
# 2      서울특별시 용산구 용산동2가    61.17  202412   31  25000  1994.0    신흥로25가길
# 3        서울특별시 광진구 중곡동    40.80  202412   31  11000  1990.0     능동로43길
# 4      서울특별시 성동구 성수동2가    50.00  202412   31  16000  1995.0       성덕정길
# ...                ...      ...     ...  ...    ...     ...        ...
# 55281    서울특별시 송파구 마천동    18.75  202306    1   2000  1985.0   성내천로29다길
# 55282    서울특별시 송파구 방이동    43.00  202306    1  24000  2019.0        NaN
# 55283    서울특별시 송파구 방이동    43.00  202306    1  24000  2019.0   백제고분로48길
# 55284    서울특별시 송파구 방이동    43.00  202306    1  14000  1996.0    위례성대로2길
# 55285    서울특별시 강동구 성내동    49.65  202306    1  17500  1976.0  천호대로168다길
#
#                 계약기간 계약구분 갱신요구권 사용  ...    구  전세전환_갱신 계약개월수 is_계약개월수_missing  \
# ...

# %% [markdown]
# ### 아파트

# %%
apt = pd.read_csv('D:/SDC_project/아파트_전세가율.csv')
apt
# Out:
#         Unnamed: 0              시군구     구      동  전용면적(㎡)    계약년월  계약일  \
# 0                0     서울특별시 중구 신당동    중구    신당동    84.88  202312   31
# 1                1    서울특별시 용산구 이촌동   용산구    이촌동    59.22  202312   31
# 2                2    서울특별시 용산구 효창동   용산구    효창동    59.41  202312   31
# 3                3    서울특별시 용산구 효창동   용산구    효창동    59.41  202312   31
# 4                4  서울특별시 성동구 금호동2가   성동구  금호동2가    59.98  202312   31
# ...            ...              ...   ...    ...      ...     ...  ...
# 221511      237179  서울특별시 영등포구 여의도동  영등포구   여의도동    93.06  202401    1
# 221512      237180  서울특별시 성동구 하왕십리동   성동구  하왕십리동    51.94  202401    1
# 221513      237181  서울특별시 서대문구 북아현동  서대문구   북아현동    59.96  202401    1
# 221514      237182    서울특별시 송파구 장지동   송파구    장지동    84.98  202401    1
# 221515      237183    서울특별시 송파구 신천동   송파구    신천동    84.79  202401    1
#
#            전세금  건축년도         도로명  ... 주택유형        계약시기 전세전환_갱신 계약개월수  \
# ...

# %% [markdown]
# ### 오피스텔

# %%
officetel = pd.read_csv('D:/SDC_project/오피스텔_전세가율.csv')
officetel
# Out:
#        Unnamed: 0               시군구     구      동  전용면적(㎡)    계약년월  계약일    전세금  \
# 0               0   서울특별시 동대문구 답십리동  동대문구   답십리동    20.62  202312   30  13000
# 1               1      서울특별시 도봉구 창동   도봉구     창동    29.16  202312   30  18600
# 2               2     서울특별시 중랑구 신내동   중랑구    신내동    27.79  202312   30  18000
# 3               3    서울특별시 동대문구 전농동  동대문구    전농동    18.43  202312   30  21000
# 4               4      서울특별시 도봉구 창동   도봉구     창동    29.16  202312   30  18600
# ...           ...               ...   ...    ...      ...     ...  ...    ...
# 40070       40542     서울특별시 은평구 응암동   은평구    응암동    33.85  202401    1  23300
# 40071       40543     서울특별시 중랑구 신내동   중랑구    신내동    29.90  202401    1  20000
# 40072       40544   서울특별시 성북구 동선동1가   성북구  동선동1가    17.72  202401    1   8400
# 40073       40545      서울특별시 중구 중림동    중구    중림동    17.25  202401    1  22000
# 40074       40546  서울특별시 영등포구 양평동5가  영등포구  양평동5가    28.60  202401    1  28800
#
# ...

# %% [markdown]
# ### 연립다세대

# %%
town_house = pd.read_csv('D:/SDC_project/연립다세대_전세가율.csv')
town_house
# Out:
#                   시군구  전용면적(㎡)    계약년월  계약일    전세금  건축년도           도로명  \
# 0       서울특별시 중랑구 상봉동    25.91  202306   23  25000  2023     면목로92가길 4
# 1       서울특별시 성북구 정릉동    29.61  202306   23  21000  2018  보국문로11길 28-7
# 2       서울특별시 중랑구 면목동    17.54  202306   23  14000  2023     면목로65길 27
# 3       서울특별시 성북구 장위동    59.64  202306   23  11000  1991     장위로31길 16
# 4       서울특별시 송파구 석촌동    40.80  202306   23  20000  2002     삼학사로6길 13
# ...               ...      ...     ...  ...    ...   ...           ...
# 91503   서울특별시 중랑구 면목동    18.20  202412   31  15400  2018     면목로42길 11
# 91504   서울특별시 용산구 효창동    27.94  202412   31  24255  2017   효창원로69가길 28
# 91505  서울특별시 용산구 이태원동    91.71  202412   31  40000  1994     보광로55길 15
# 91506   서울특별시 광진구 중곡동    30.00  202412   31   7203  2022       면목로 119
# 91507   서울특별시 용산구 후암동    15.12  202412   31  12000  2013   두텁바위로25길 30
#
#                 계약기간 계약구분 갱신요구권 사용  ...    구  전세전환_갱신 계약개월수 is_계약개월수_missing  \
# ...

# %%
print("아파트 컬럼:", apt.columns.tolist())
print("오피스텔 컬럼:", officetel.columns.tolist())
print("다세대주택 컬럼:", multi_household.columns.tolist())
print("연립주택 컬럼:", town_house.columns.tolist())
# Out:
# 아파트 컬럼: ['Unnamed: 0', '시군구', '구', '동', '전용면적(㎡)', '계약년월', '계약일', '전세금', '건축년도', '도로명', '계약기간', '계약구분', '갱신요구권 사용', '종전계약 보증금(만원)', '종전계약 월세(만원)', '주택유형', '계약시기', '전세전환_갱신', '계약개월수', 'is_계약개월수_missing', 'is_갱신요구권_사용_originally_missing', 'is_건축년도_missing', '평균전세금', '평균매매가', '전세가율']
# 오피스텔 컬럼: ['Unnamed: 0', '시군구', '구', '동', '전용면적(㎡)', '계약년월', '계약일', '전세금', '건축년도', '도로명', '계약기간', '계약구분', '갱신요구권 사용', '종전계약 보증금(만원)', '종전계약 월세(만원)', '주택유형', '계약시기', '전세전환_갱신', '계약개월수', 'is_계약개월수_missing', 'is_갱신요구권_사용_originally_missing', 'is_건축년도_missing', '평균전세금', '평균매매가', '전세가율']
# 다세대주택 컬럼: ['시군구', '전용면적(㎡)', '계약년월', '계약일', '전세금', '건축년도', '도로명', '계약기간', '계약구분', '갱신요구권 사용', '종전계약 보증금(만원)', '종전계약 월세(만원)', '주택유형', '계약시기', '구', '전세전환_갱신', '계약개월수', 'is_계약개월수_missing', '동', 'is_갱신요구권_사용_originally_missing', 'is_건축년도_missing', '평균 매매가', '평균 보증금', '전세가율']
# ...

# %%
common_columns = set(apt.columns)
common_columns &= set(officetel.columns)
common_columns &= set(multi_household.columns)
common_columns &= set(town_house.columns)

common_columns = list(common_columns)

# %%
columns_to_keep = [
    '시군구', '구', '동', '전용면적(㎡)', '계약년월', '계약일', '전세금', '건축년도', '도로명',
    '계약기간', '계약구분', '갱신요구권 사용', '종전계약 보증금(만원)', '종전계약 월세(만원)',
    '주택유형', '계약시기', '전세전환_갱신', '계약개월수', 'is_계약개월수_missing',
    'is_갱신요구권_사용_originally_missing', 'is_건축년도_missing',
    '평균전세금', '평균매매가', '전세가율'
]

# %%
def align_columns(df):
    return df[[col for col in columns_to_keep if col in df.columns]]

apt_df_aligned = align_columns(apt)
officetel_df_aligned = align_columns(officetel)
multi_df_aligned = align_columns(multi_household)
town_df_aligned = align_columns(town_house)

# %%
total_df = pd.concat(
    [apt_df_aligned, officetel_df_aligned, multi_df_aligned, town_df_aligned]
)

# %%
total_df
# Out:
#                    시군구    구      동  전용면적(㎡)    계약년월  계약일    전세금    건축년도  \
# 0         서울특별시 중구 신당동   중구    신당동    84.88  202312   31  60000  1999.0
# 1        서울특별시 용산구 이촌동  용산구    이촌동    59.22  202312   31  40000  1994.0
# 2        서울특별시 용산구 효창동  용산구    효창동    59.41  202312   31  67000  2010.0
# 3        서울특별시 용산구 효창동  용산구    효창동    59.41  202312   31  67000  2010.0
# 4      서울특별시 성동구 금호동2가  성동구  금호동2가    59.98  202312   31  66150  2016.0
# ...                ...  ...    ...      ...     ...  ...    ...     ...
# 91503    서울특별시 중랑구 면목동  중랑구    면목동    18.20  202412   31  15400  2018.0
# 91504    서울특별시 용산구 효창동  용산구    효창동    27.94  202412   31  24255  2017.0
# 91505   서울특별시 용산구 이태원동  용산구   이태원동    91.71  202412   31  40000  1994.0
# 91506    서울특별시 광진구 중곡동  광진구    중곡동    30.00  202412   31   7203  2022.0
# 91507    서울특별시 용산구 후암동  용산구    후암동    15.12  202412   31  12000  2013.0
#
#                도로명           계약기간  ...   주택유형        계약시기 전세전환_갱신  계약개월수  \
# ...

# %%
total_df.isnull().sum()
# Out:
# 시군구                                   0
# 구                                     0
# 동                                   880
# 전용면적(㎡)                               0
# 계약년월                                  0
# 계약일                                   0
# 전세금                                   0
# 건축년도                                  0
# 도로명                                2586
# 계약기간                                  0
# 계약구분                                  0
# 갱신요구권 사용                              0
# 종전계약 보증금(만원)                          0
# 종전계약 월세(만원)                           0
# 주택유형                                  0
# 계약시기                                  0
# 전세전환_갱신                               0
# 계약개월수                                 0
# is_계약개월수_missing                      0
# is_갱신요구권_사용_originally_missing        0
# is_건축년도_missing                       0
# 평균전세금                             55286
# 평균매매가                             55286
# ...

# %%
total_df.columns
# Out:
# Index(['동', '도로명', '계약기간', '계약일', '전세금', '종전계약 월세(만원)', '계약년월', '계약개월수', '구',
#        'is_계약개월수_missing', '전세전환_갱신', '종전계약 보증금(만원)', '주택유형', '시군구', '건축년도',
#        '계약구분', '전세가율', '계약시기', 'is_건축년도_missing',
#        'is_갱신요구권_사용_originally_missing', '전용면적(㎡)', '갱신요구권 사용'],
#       dtype='object')

# %%
total_df.isnull().sum()
# Out:
# 동                                  880
# 도로명                               2586
# 계약기간                                 0
# 계약일                                  0
# 전세금                                  0
# 종전계약 월세(만원)                          0
# 계약년월                                 0
# 계약개월수                                0
# 구                                    0
# is_계약개월수_missing                     0
# 전세전환_갱신                              0
# 종전계약 보증금(만원)                         0
# 주택유형                                 0
# 시군구                                  0
# 건축년도                                 0
# 계약구분                                 0
# 전세가율                                 0
# 계약시기                                 0
# is_건축년도_missing                      0
# is_갱신요구권_사용_originally_missing       0
# 전용면적(㎡)                              0
# 갱신요구권 사용                             0
# dtype: int64

# %%
total_df[total_df['동'].isna()]
# Out:
#           동      도로명           계약기간  계약일     전세금  종전계약 월세(만원)    계약년월  계약개월수  \
# 261596  NaN   자양로50길  202502~202702   31   18000          0.0  202412   24.0
# 261666  NaN  자양로23가길  202501~202601   30   21000          0.0  202412   12.0
# 261667  NaN  자양로23나길  202502~202702   30   11000          0.0  202412   24.0
# 261801  NaN    구의로9길  202502~202702   28    9800          0.0  202412   24.0
# 261860  NaN     비봉5길  202503~202903   27  120000          0.0  202412   48.0
# ...     ...      ...            ...  ...     ...          ...     ...    ...
# 316688  NaN  자양로23나길  202307~202507    2   15000          0.0  202306   24.0
# 316857  NaN   자양로30길  202307~202507    1   20000          0.0  202306   24.0
# 316858  NaN   자양로23길  202307~202507    1   17000          0.0  202306   24.0
# 316859  NaN   자양로32길  202306~202506    1    9000          0.0  202306   24.0
# 316860  NaN   자양로30길  202307~202507    1   20000          0.0  202306   24.0
#
# ...

# %%
# 1) 필요한 컬럼 정리
df = total_df[['주택유형','구','동', '전용면적(㎡)', '전세금', '계약시기', '건축년도', '계약구분', '종전계약 보증금(만원)','전세가율']]

# 2) 계약연월 컬럼 만들기
df['계약시기'] = df['계약시기'].astype(str)

# 3) 건축년도 구간화
df['건축연도대'] = pd.cut(df['건축년도'], bins=[1900, 1989, 1999, 2009, 2019, 2031],
                        labels=['~1989', '1990s', '2000s', '2010s', '2020s'])

# 4) 면적 구간화
df['면적대'] = pd.cut(df['전용면적(㎡)'], bins=[0, 30, 50, 70, 100, 999],
                     labels=['~30', '30-50', '50-70', '70-100', '100+'])
# Out:
# C:\Users\emily\AppData\Local\Temp\ipykernel_26240\1641233031.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['계약시기'] = df['계약시기'].astype(str)
# C:\Users\emily\AppData\Local\Temp\ipykernel_26240\1641233031.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['건축연도대'] = pd.cut(df['건축년도'], bins=[1900, 1989, 1999, 2009, 2019, 2031],
# C:\Users\emily\AppData\Local\Temp\ipykernel_26240\1641233031.py:12: SettingWithCopyWarning:
# ...
