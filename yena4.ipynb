# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %% [markdown]
# ### 단독/다가구

# %%
multi_household = pd.read_csv('D:/SDC_project/단독다가구_전세가율_중복허용.csv')
multi_household
# Out:
#                    시군구    구      동  전용면적(㎡)    계약년월  계약일    전세금    건축년도  \
# 0        서울특별시 성동구 행당동  성동구    행당동    42.00  202412   31  14000  1998.0
# 1        서울특별시 용산구 서계동  용산구    서계동    26.45  202412   31   3000  1944.0
# 2      서울특별시 용산구 용산동2가  용산구  용산동2가    61.17  202412   31  25000  1994.0
# 3        서울특별시 광진구 중곡동  광진구    중곡동    40.80  202412   31  11000  1990.0
# 4      서울특별시 성동구 성수동2가  성동구  성수동2가    50.00  202412   31  16000  1995.0
# ...                ...  ...    ...      ...     ...  ...    ...     ...
# 55281    서울특별시 송파구 마천동  송파구    마천동    18.75  202306    1   2000  1985.0
# 55282    서울특별시 송파구 방이동  송파구    방이동    43.00  202306    1  24000  2019.0
# 55283    서울특별시 송파구 방이동  송파구    방이동    43.00  202306    1  24000  2019.0
# 55284    서울특별시 송파구 방이동  송파구    방이동    43.00  202306    1  14000  1996.0
# 55285    서울특별시 강동구 성내동  강동구    성내동    49.65  202306    1  17500  1976.0
#
#              도로명           계약기간  ...   주택유형        계약시기  전세전환_갱신  계약개월수  \
# ...

# %% [markdown]
# ### 아파트

# %%
apt = pd.read_csv('D:/SDC_project/아파트_전세가율_중복허용.csv')
apt = apt.iloc[:, 1:]
apt
# Out:
#                     시군구     구      동  전용면적(㎡)    계약년월  계약일     전세금  건축년도  \
# 0          서울특별시 중구 신당동    중구    신당동    84.88  202312   31   60000  1999
# 1         서울특별시 용산구 이촌동   용산구    이촌동    59.22  202312   31   40000  1994
# 2         서울특별시 용산구 효창동   용산구    효창동    59.41  202312   31   67000  2010
# 3         서울특별시 용산구 효창동   용산구    효창동    59.41  202312   31   67000  2010
# 4       서울특별시 성동구 금호동2가   성동구  금호동2가    59.98  202312   31   66150  2016
# ...                 ...   ...    ...      ...     ...  ...     ...   ...
# 237179  서울특별시 영등포구 여의도동  영등포구   여의도동    93.06  202401    1   40000  1976
# 237180  서울특별시 성동구 하왕십리동   성동구  하왕십리동    51.94  202401    1   50000  2017
# 237181  서울특별시 서대문구 북아현동  서대문구   북아현동    59.96  202401    1   40000  1999
# 237182    서울특별시 송파구 장지동   송파구    장지동    84.98  202401    1   69000  2008
# 237183    서울특별시 송파구 신천동   송파구    신천동    84.79  202401    1  105000  2008
#
#                도로명           계약기간  ... 주택유형        계약시기 전세전환_갱신  계약개월수  \
# ...

# %% [markdown]
# ### 오피스텔

# %%
officetel = pd.read_csv('D:/SDC_project/오피스텔_전세가율_중복허용.csv')
officetel = officetel.iloc[:, 1:]
officetel
# Out:
#                     시군구     구      동  전용면적(㎡)    계약년월  계약일    전세금    건축년도  \
# 0       서울특별시 동대문구 답십리동  동대문구   답십리동    20.62  202312   30  13000  2015.0
# 1          서울특별시 도봉구 창동   도봉구     창동    29.16  202312   30  18600  2019.0
# 2         서울특별시 중랑구 신내동   중랑구    신내동    27.79  202312   30  18000  2021.0
# 3        서울특별시 동대문구 전농동  동대문구    전농동    18.43  202312   30  21000  2023.0
# 4          서울특별시 도봉구 창동   도봉구     창동    29.16  202312   30  18600  2019.0
# ...                 ...   ...    ...      ...     ...  ...    ...     ...
# 40542     서울특별시 은평구 응암동   은평구    응암동    33.85  202401    1  23300  2021.0
# 40543     서울특별시 중랑구 신내동   중랑구    신내동    29.90  202401    1  20000  2021.0
# 40544   서울특별시 성북구 동선동1가   성북구  동선동1가    17.72  202401    1   8400  2013.0
# 40545      서울특별시 중구 중림동    중구    중림동    17.25  202401    1  22000  2023.0
# 40546  서울특별시 영등포구 양평동5가  영등포구  양평동5가    28.60  202401    1  28800  2017.0
#
#               도로명           계약기간  ...  주택유형        계약시기 전세전환_갱신  계약개월수  \
# ...

# %% [markdown]
# ### 연립다세대

# %%
town_house = pd.read_csv('D:/SDC_project/연립다세대_전세가율_중복허용.csv')
town_house
# Out:
#                    시군구  전용면적(㎡)    계약년월  계약일    전세금  건축년도           도로명  \
# 0        서울특별시 중랑구 상봉동    25.91  202306   23  25000  2023     면목로92가길 4
# 1        서울특별시 성북구 정릉동    29.61  202306   23  21000  2018  보국문로11길 28-7
# 2        서울특별시 중랑구 면목동    17.54  202306   23  14000  2023     면목로65길 27
# 3        서울특별시 성북구 장위동    59.64  202306   23  11000  1991     장위로31길 16
# 4        서울특별시 송파구 석촌동    40.80  202306   23  20000  2002     삼학사로6길 13
# ...                ...      ...     ...  ...    ...   ...           ...
# 96971    서울특별시 용산구 효창동    27.94  202412   31  24255  2017   효창원로69가길 28
# 96972   서울특별시 용산구 이태원동    91.71  202412   31  40000  1994     보광로55길 15
# 96973    서울특별시 광진구 중곡동    30.00  202412   31   7203  2022       면목로 119
# 96974  서울특별시 성동구 성수동2가    14.04  202412   31  10290  2014      광나루로4길 6
# 96975    서울특별시 용산구 후암동    15.12  202412   31  12000  2013   두텁바위로25길 30
#
#                 계약기간 계약구분 갱신요구권 사용  ...    구  전세전환_갱신 계약개월수 is_계약개월수_missing  \
# ...

# %%
# columns_to_keep = [
#     '시군구', '구', '동', '전용면적(㎡)', '계약년월', '계약일', '전세금', '건축년도', '도로명',
#     '계약기간', '계약구분', '갱신요구권 사용', '종전계약 보증금(만원)', '종전계약 월세(만원)',
#     '주택유형', '계약시기', '전세전환_갱신', '계약개월수', 'is_계약개월수_missing',
#     'is_갱신요구권_사용_originally_missing', 'is_건축년도_missing',
#     '평균전세금', '평균매매가', '전세가율'
# ]

# %%
# def align_columns(df):
#     return df[[col for col in columns_to_keep if col in df.columns]]

# apt_df_aligned = align_columns(apt)
# officetel_df_aligned = align_columns(officetel)
# multi_df_aligned = align_columns(multi_household)
# town_df_aligned = align_columns(town_house)

# %%
total_df = pd.concat(
    [multi_household, apt, officetel, town_house]
)

# %%
total_df
# Out:
#                    시군구    구      동  전용면적(㎡)    계약년월  계약일    전세금    건축년도  \
# 0        서울특별시 성동구 행당동  성동구    행당동    42.00  202412   31  14000  1998.0
# 1        서울특별시 용산구 서계동  용산구    서계동    26.45  202412   31   3000  1944.0
# 2      서울특별시 용산구 용산동2가  용산구  용산동2가    61.17  202412   31  25000  1994.0
# 3        서울특별시 광진구 중곡동  광진구    중곡동    40.80  202412   31  11000  1990.0
# 4      서울특별시 성동구 성수동2가  성동구  성수동2가    50.00  202412   31  16000  1995.0
# ...                ...  ...    ...      ...     ...  ...    ...     ...
# 96971    서울특별시 용산구 효창동  용산구    효창동    27.94  202412   31  24255  2017.0
# 96972   서울특별시 용산구 이태원동  용산구   이태원동    91.71  202412   31  40000  1994.0
# 96973    서울특별시 광진구 중곡동  광진구    중곡동    30.00  202412   31   7203  2022.0
# 96974  서울특별시 성동구 성수동2가  성동구  성수동2가    14.04  202412   31  10290  2014.0
# 96975    서울특별시 용산구 후암동  용산구    후암동    15.12  202412   31  12000  2013.0
#
#                도로명           계약기간  ...   주택유형        계약시기 전세전환_갱신  계약개월수  \
# ...

# %%
total_df.columns
# Out:
# Index(['시군구', '구', '동', '전용면적(㎡)', '계약년월', '계약일', '전세금', '건축년도', '도로명', '계약기간',
#        '계약구분', '갱신요구권 사용', '종전계약 보증금(만원)', '종전계약 월세(만원)', '주택유형', '계약시기',
#        '전세전환_갱신', '계약개월수', 'is_계약개월수_missing',
#        'is_갱신요구권_사용_originally_missing', 'is_건축년도_missing', '평균전세금', '평균매매가',
#        '전세가율'],
#       dtype='object')

# %%
total_df.isnull().sum()
# Out:
# 시군구                                  0
# 구                                    0
# 동                                    0
# 전용면적(㎡)                              0
# 계약년월                                 0
# 계약일                                  0
# 전세금                                  0
# 건축년도                                 0
# 도로명                               2586
# 계약기간                                 0
# 계약구분                                 0
# 갱신요구권 사용                             0
# 종전계약 보증금(만원)                         0
# 종전계약 월세(만원)                          0
# 주택유형                                 0
# 계약시기                                 0
# 전세전환_갱신                              0
# 계약개월수                                0
# is_계약개월수_missing                     0
# is_갱신요구권_사용_originally_missing       0
# is_건축년도_missing                      0
# 평균전세금                                0
# 평균매매가                                0
# 전세가율                                 0
# dtype: int64

# %%
total_df[total_df.duplicated()]
# Out:
#                    시군구    구      동  전용면적(㎡)    계약년월  계약일    전세금    건축년도  \
# 72      서울특별시 용산구 서빙고동  용산구   서빙고동    53.61  202412   30  15000  1990.0
# 129      서울특별시 강남구 대치동  강남구    대치동    40.00  202412   30  21000  2003.0
# 144    서울특별시 성북구 동선동3가  성북구  동선동3가    36.20  202412   29   8000  1990.0
# 163      서울특별시 용산구 후암동  용산구    후암동    45.00  202412   28  20000  1941.0
# 176      서울특별시 강동구 성내동  강동구    성내동    23.00  202412   28  10000  1993.0
# ...                ...  ...    ...      ...     ...  ...    ...     ...
# 96921    서울특별시 송파구 문정동  송파구    문정동    22.56  202412   31  17500  2018.0
# 96923    서울특별시 송파구 삼전동  송파구    삼전동    39.80  202412   31  18300  2004.0
# 96929    서울특별시 강남구 논현동  강남구    논현동    15.36  202412   31  18500  2013.0
# 96965    서울특별시 은평구 역촌동  은평구    역촌동    29.86  202412   31  22000  2018.0
# 96974  서울특별시 성동구 성수동2가  성동구  성수동2가    14.04  202412   31  10290  2014.0
#
#                  도로명           계약기간  ...   주택유형        계약시기 전세전환_갱신  계약개월수  \
# ...

# %%
# 1) 필요한 컬럼 정리
# total_df = total_total_df[['주택유형','구','동', '전용면적(㎡)', '전세금', '계약시기', '건축년도', '계약구분', '종전계약 보증금(만원)','전세가율']]

# 2) 계약연월 컬럼 만들기
total_df['계약시기'] = total_df['계약시기'].astype(str)

# 3) 건축년도 구간화
total_df['건축연도대'] = pd.cut(total_df['건축년도'], bins=[1900, 1989, 1999, 2009, 2019, 2031],
                        labels=['~1989', '1990s', '2000s', '2010s', '2020s'])

# 4) 면적 구간화
total_df['면적대'] = pd.cut(total_df['전용면적(㎡)'], bins=[0, 30, 50, 70, 100, 999],
                     labels=['~30', '30-50', '50-70', '70-100', '100+'])

# %%
# 유사 조건 그룹 생성
total_df['조건그룹'] = total_df[['구', '건축연도대', '면적대']].astype(str).agg('_'.join, axis=1)

# 그룹별 평균/표준편차
group_stats = total_df.groupby('조건그룹')['전세금'].agg(['mean', 'std']).reset_index()
group_stats.columns = ['조건그룹', '보증금_평균', '보증금_표준편차']

# 병합 후 z-score 계산
total_df = total_df.merge(group_stats, on='조건그룹', how='left')
total_df['보증금_zscore'] = (total_df['전세금'] - total_df['보증금_평균']) / total_df['보증금_표준편차']
total_df['보증금_이상치'] = total_df['보증금_zscore'].abs() > 2  # Z-score 2 초과이면 이상치

# %%
total_df['도로명_연월'] = total_df['구'] + '_' + total_df['계약시기']
주소_빈도 = total_df['도로명_연월'].value_counts().reset_index()
주소_빈도.columns = ['도로명_연월', '주소_해당월_거래수']

# 병합
total_df = total_df.merge(주소_빈도, on='도로명_연월', how='left')
total_df['거래_집중의심'] = total_df['주소_해당월_거래수'] >= 3

# %%
total_df['노후건물'] = total_df['건축년도'] < 1990
total_df['노후_이상보증'] = total_df['노후건물'] & total_df['보증금_이상치']

# %%
# 1. 기본 지표 집계
구별_지표 = total_df.groupby('구').agg({
    '보증금_이상치': 'sum',
    '거래_집중의심': 'sum',
    '노후_이상보증': 'sum',
    '도로명': 'count',  # 총 거래 수
    '전세가율': 'mean'  # 전세가율은 평균으로 사용
}).reset_index()

# 2. 비율 계산
구별_지표['보증금_이상비율'] = 구별_지표['보증금_이상치'] / 구별_지표['도로명']
구별_지표['거래집중비율'] = 구별_지표['거래_집중의심'] / 구별_지표['도로명']
구별_지표['노후이상비율'] = 구별_지표['노후_이상보증'] / 구별_지표['도로명']

# %%
# 각 비율 및 전세가율을 정규화 (Z-score 방식 또는 Min-Max 가능)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
score_cols = ['보증금_이상비율', '거래집중비율', '노후이상비율', '전세가율']
구별_지표[[f'{col}_score' for col in score_cols]] = scaler.fit_transform(구별_지표[score_cols])

# 4. 위험 점수 = 단순 평균 (가중치 주고 싶으면 각자 곱해주기)
구별_지표['위험스코어'] = 구별_지표[[f'{col}_score' for col in score_cols]].mean(axis=1)

# 5. 정렬
구별_지표 = 구별_지표.sort_values('위험스코어', ascending=False)

# 위험 상위 구 보기
상위구 = 구별_지표.sort_values('위험스코어', ascending=False).head(5)

# %%
상위구
# Out:
#       구  보증금_이상치  거래_집중의심  노후_이상보증    도로명       전세가율  보증금_이상비율    거래집중비율  \
# 8   노원구     1108    21465      458  21427  49.829201  0.051710  1.001773
# 4   관악구      678    15691       89  15202  46.448268  0.044599  1.032167
# 9   도봉구      474    10012      150  10045  56.223778  0.047188  0.996715
# 3   강서구     1504    30438       46  30358  65.534547  0.049542  1.002635
# 18  양천구      918    19160      246  19117  49.244567  0.048020  1.002249
#
#       노후이상비율  보증금_이상비율_score  거래집중비율_score  노후이상비율_score  전세가율_score     위험스코어
# 8   0.021375        1.000000      0.226386      1.000000    0.520559  0.686736
# 4   0.005854        0.609737      1.000000      0.218495    0.417348  0.561395
# 9   0.014933        0.751783      0.097625      0.675619    0.715768  0.560199
# 3   0.001515        0.881000      0.248320      0.000000    1.000000  0.532330
# 18  0.012868        0.797468      0.238498      0.571655    0.502711  0.527583

# %%
구별_지표.sort_values(by='위험스코어',ascending=False)
# Out:
#        구  보증금_이상치  거래_집중의심  노후_이상보증    도로명       전세가율  보증금_이상비율    거래집중비율  \
# 4    관악구      678    15691       89  15202  46.448268  0.044599  1.032167
# 8    노원구     1108    21465      458  21427  49.829201  0.051710  1.001773
# 9    도봉구      474    10012      150  10045  56.223778  0.047188  0.996715
# 18   양천구      918    19160      246  19117  49.244567  0.048020  1.002249
# 19  영등포구     1006    22236      173  22078  53.502916  0.045566  1.007156
# 16   성북구      693    15139       48  14982  54.231164  0.046256  1.010479
# 3    강서구     1504    30438       46  30358  65.534547  0.049542  1.002635
# 11   동작구      768    16893       71  16671  44.946320  0.046068  1.013317
# 24   중랑구      608    14983       65  14823  54.210464  0.041017  1.010794
# 10  동대문구      528    14312       64  14188  61.148293  0.037215  1.008740
# 1    강동구     1067    25103      163  24991  53.212094  0.042695  1.004482
# 6    구로구      628    14755       84  14711  56.907137  0.042689  1.002991
# ...
